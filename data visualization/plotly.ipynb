# %%
import plotly.express as px
import pandas as pd
import seaborn as sns

# %% [markdown]
# for this we have to install nbformat

# %%
df=sns.load_dataset("car_crashes")
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
#total Accidents by states
fig=px.bar(df,x='abbrev',y='total',
           title="Total Accident By State",
           labels={'abbrev':'states','total':'total Accidents'},
           color="total",
           color_continuous_scale="Blues")
fig.show()

# %%
#percentage 
fig=px.pie(df,values ='speeding',names='abbrev',
           title="percentage of speeding Acccidents by state",
           labels={'abbrev':'State','speeding':'speeding Accidents'},
           color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()

# %%
#percentage 
fig=px.pie(df,values ='speeding',names='abbrev',
           title="percentage of speeding Acccidents by state",
           labels={'abbrev':'State','speeding':'speeding Accidents'},
           color_discrete_sequence=px.colors.sequential.RdBu)
fig.update_traces(textposition='inside',textinfo='percent+label',pull=[0.05]*len(df))# it gives spaces between values
fig.show()

# %%
# Manually map states to regions
region_map = {
    'CT': 'Northeast', 'ME': 'Northeast', 'MA': 'Northeast', 'NH': 'Northeast', 'RI': 'Northeast', 'VT': 'Northeast',
    'NJ': 'Northeast', 'NY': 'Northeast', 'PA': 'Northeast',
    'IL': 'Midwest', 'IN': 'Midwest', 'MI': 'Midwest', 'OH': 'Midwest', 'WI': 'Midwest',
    'IA': 'Midwest', 'KS': 'Midwest', 'MN': 'Midwest', 'MO': 'Midwest', 'NE': 'Midwest', 'ND': 'Midwest', 'SD': 'Midwest',
    'DE': 'South', 'FL': 'South', 'GA': 'South', 'MD': 'South', 'NC': 'South', 'SC': 'South', 'VA': 'South', 'DC': 'South',
    'WV': 'South', 'AL': 'South', 'KY': 'South', 'MS': 'South', 'TN': 'South', 'AR': 'South', 'LA': 'South', 'OK': 'South', 'TX': 'South',
    'AZ': 'West', 'CO': 'West', 'ID': 'West', 'MT': 'West', 'NV': 'West', 'NM': 'West', 'UT': 'West', 'WY': 'West',
    'AK': 'West', 'CA': 'West', 'HI': 'West', 'OR': 'West', 'WA': 'West'
}

# Add region column using abbrev
df['region'] = df['abbrev'].map(region_map)

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
#sunburst chart of region wise and statewise speeding accidents
fig=px.sunburst(df,
                path=['region','abbrev'],
                values='speeding',
                title="Sunburst Chart of speeding accidents by Region and state",
                color='speeding',
                color_continuous_scale='Reds',
                template='plotly_dark')
fig.show()

# %%
#Alcohol vs Speeding
fig=px.scatter(df,x='speeding',y='alcohol',
               color='abbrev',
               size='total',
               title='Speeding vs Alcohol involvement in Accidents',
               labels={'speeding':'Speeding Accidents','alcohol':'Alcohol Involvement'}
               )
fig.update_layout(title={'x':0.5})
fig.show()

# %%
melted_df=df.melt(id_vars=['abbrev'],value_vars=['speeding','alcohol','not_distracted'])
fig=px.bar(melted_df,x='abbrev',y='value',color='variable',
           animation_frame='variable',
           title='Animated Comprisonof Speeding,Alcohol and Not Discrated Accidents',
           labels={'value':'Percentage'}
           )
fig.show()

# %%
fig=px.choropleth(df,
                   locations='abbrev',
                   locationmode='USA-states',
                   color='total',
                   title='Total Accidents by US states'
                   )
fig.show()

# %%
fig=px.box(df,x='region',y='ins_premium',
           title='Insurence premium by Region',
           color='region')
fig.show()

# %%
#total accidents vs speeding
fig=px.scatter(df,x='total',y='speeding',
           size='alcohol',color='region',
           title='total Accidents vs Speeding Accidents',
           hover_name='abbrev',
           size_max=40)# hover name is used to give heading name
fig.show()

# %%
#top 10 state by Insurence Premium
# top 10 =df.nlargest(10,'ins_premium')
top10=df.sort_values('ins_premium',ascending=False).head(10)
fig=px.bar(top10,x='abbrev',y='ins_premium',color='ins_premium',
           title='top 10 states by Insurance premium',
           labels={'abbrev':'State','ins_premium':'Insurance Premium'},
           color_continuous_scale='viridis')
fig.show()

# %% [markdown]
# ## practise question

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("taxis")
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.dropna(subset=['pickup_zone'],inplace=True)
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            43
# pickup_zone         0
# dropoff_zone       24
# pickup_borough      0
# dropoff_borough    24
# dtype: int64

# %%
fig =px.pie(df,names='pickup_zone',values='distance',
          title="pickup vs dropoff chart",
          color='pickup',
          )
fig.show()

# %%
fig =px.pie(df,names='pickup_zone',values='distance',
          title="pickup vs dropoff chart",
          color='pickup',
          )
fig.update_traces(textposition='inside',textinfo='percent+label',pull=[0.05]*len(df))
fig.show()

# %%
pickup_zone_directions = {
    "Lenox Hill West": "East",
    "Upper West Side South": "West",
    "Alphabet City": "East",
    "Hudson Sq": "Other",
    "Midtown East": "Central",
    "Times Sq/Theatre District": "Central",
    "Battery Park City": "South",
    "Murray Hill": "Other",
    "East Harlem South": "North",
    "Lincoln Square East": "Other",
    "LaGuardia Airport": "Airport",
    "Lincoln Square West": "Other",
    "Financial District North": "South",
    "Upper West Side North": "West",
    "East Chelsea": "Other",
    "Midtown Center": "Central",
    "Gramercy": "Other",
    "Penn Station/Madison Sq West": "Other",
    "Sutton Place/Turtle Bay North": "Other",
    "West Chelsea/Hudson Yards": "Other",
    "Clinton East": "Other",
    "Clinton West": "Other",
    "UN/Turtle Bay South": "Other",
    "Midtown South": "Central",
    "Midtown North": "Central",
    "Garment District": "Other",
    "Lenox Hill East": "East",
    "Flatiron": "Other",
    "TriBeCa/Civic Center": "Other",
    "Upper East Side North": "East",
    "West Village": "Other",
    "Greenwich Village South": "Other",
    "JFK Airport": "Airport",
    "East Village": "East",
    "Union Sq": "Other",
    "Yorkville West": "East",
    "Central Park": "Central",
    "Meatpacking/West Village West": "Other",
    "Kips Bay": "Other",
    "Morningside Heights": "Other",
    "Astoria": "Queens",
    "East Tremont": "Bronx",
    "Upper East Side South": "East",
    "Financial District South": "South",
    "Bloomingdale": "West",
    "Queensboro Hill": "Queens",
    "SoHo": "Other",
    "Brooklyn Heights": "Brooklyn",
    "Yorkville East": "East",
    "Manhattan Valley": "Other",
    "DUMBO/Vinegar Hill": "Other",
    "Little Italy/NoLiTa": "Other",
    "Mott Haven/Port Morris": "Other",
    "Greenwich Village North": "Other",
    "Stuyvesant Heights": "Other",
    "Lower East Side": "East",
    "East Harlem North": "North",
    "Chinatown": "Other",
    "Fort Greene": "Other",
    "Steinway": "Other",
    "Central Harlem": "North",
    "Crown Heights North": "Other",
    "Seaport": "Other",
    "Two Bridges/Seward Park": "Other",
    "Boerum Hill": "Other",
    "Williamsburg (South Side)": "Brooklyn",
    "Rosedale": "Other",
    "Flushing": "Queens",
    "Old Astoria": "Queens",
    "Soundview/Castle Hill": "Other",
    "Stuy Town/Peter Cooper Village": "Other",
    "World Trade Center": "Other",
    "Sunnyside": "Other",
    "Washington Heights South": "North",
    "Prospect Heights": "Other",
    "East New York": "Other",
    "Hamilton Heights": "Other",
    "Cobble Hill": "Other",
    "Long Island City/Queens Plaza": "Queens",
    "Central Harlem North": "North",
    "Manhattanville": "Other",
    "East Flatbush/Farragut": "Other",
    "Elmhurst": "Other",
    "East Concourse/Concourse Village": "Other",
    "Park Slope": "Brooklyn",
    "Greenpoint": "Other",
    "Williamsburg (North Side)": "Brooklyn",
    "Long Island City/Hunters Point": "Other",
    "South Ozone Park": "Other",
    "Ridgewood": "Other",
    "Downtown Brooklyn/MetroTech": "Brooklyn",
    "Queensbridge/Ravenswood": "Queens",
    "Williamsbridge/Olinville": "Other",
    "Bedford": "Other",
    "Gowanus": "Other",
    "Jackson Heights": "Other",
    "South Jamaica": "Queens",
    "Bushwick North": "Brooklyn",
    "West Concourse": "Other",
    "Queens Village": "Queens",
    "Windsor Terrace": "Other",
    "Flatlands": "Other",
    "Van Cortlandt Village": "Other",
    "Woodside": "Other",
    "East Williamsburg": "Brooklyn",
    "Fordham South": "Bronx",
    "East Elmhurst": "Other",
    "Kew Gardens": "Other",
    "Flushing Meadows-Corona Park": "Queens",
    "Marine Park/Mill Basin": "Other",
    "Carroll Gardens": "Other",
    "Canarsie": "Other",
    "East Flatbush/Remsen Village": "Other",
    "Jamaica": "Queens",
    "Marble Hill": "Other",
    "Bushwick South": "Brooklyn",
    "Erasmus": "Other",
    "Claremont/Bathgate": "Other",
    "Pelham Bay": "Other",
    "Soundview/Bruckner": "Other",
    "South Williamsburg": "Brooklyn",
    "Battery Park": "South",
    "Forest Hills": "Other",
    "Maspeth": "Other",
    "Bronx Park": "Bronx",
    "Starrett City": "Other",
    "Brighton Beach": "Other",
    "Brownsville": "Other",
    "Highbridge Park": "Other",
    "Bensonhurst East": "Other",
    "Mount Hope": "Other",
    "Prospect-Lefferts Gardens": "Other",
    "Bayside": "Other",
    "Douglaston": "Other",
    "Midwood": "Other",
    "North Corona": "Other",
    "Homecrest": "Other",
    "Westchester Village/Unionport": "Other",
    "University Heights/Morris Heights": "Other",
    "Inwood": "North",
    "Washington Heights North": "North",
    "Flatbush/Ditmas Park": "Other",
    "Rego Park": "Other",
    "Riverdale/North Riverdale/Fieldston": "Other",
    "Jamaica Estates": "Queens",
    "Borough Park": "Other",
    "Sunset Park West": "Other",
    "Belmont": "Other",
    "Auburndale": "Other",
    "Schuylerville/Edgewater Park": "Other",
    "Co-Op City": "Other",
    "Crown Heights South": "Other",
    "Spuyten Duyvil/Kingsbridge": "Other",
    "Morrisania/Melrose": "Other",
    "Hollis": "Other",
    "Parkchester": "Other",
    "Coney Island": "Other",
    "East Flushing": "Queens",
    "Richmond Hill": "Other",
    "Bedford Park": "Other",
    "Highbridge": "Other",
    "Clinton Hill": "Other",
    "Sheepshead Bay": "Other",
    "Madison": "Other",
    "Dyker Heights": "Other",
    "Cambria Heights": "Other",
    "Pelham Parkway": "Other",
    "Hunts Point": "Other",
    "Melrose South": "Other",
    "Springfield Gardens North": "Other",
    "Bay Ridge": "Other",
    "Elmhurst/Maspeth": "Other",
    "Crotona Park East": "Other",
    "Bronxdale": "Bronx",
    "Briarwood/Jamaica Hills": "Queens",
    "Van Nest/Morris Park": "Other",
    "Murray Hill-Queens": "Queens",
    "Kingsbridge Heights": "Other",
    "Whitestone": "Other",
    "Saint Albans": "Other",
    "Allerton/Pelham Gardens": "Other",
    "Howard Beach": "Other",
    "Norwood": "Other",
    "Bensonhurst West": "Other",
    "Columbia Street": "Other",
    "Middle Village": "Other",
    "Prospect Park": "Other",
    "Ozone Park": "Other",
    "Gravesend": "Other",
    "Glendale": "Other",
    "Kew Gardens Hills": "Other",
    "Woodlawn/Wakefield": "Other",
    "West Farms/Bronx River": "Bronx",
    "Hillcrest/Pomonok": "Other"
}
df['pickup_region']=df['pickup_zone'].map(pickup_zone_directions)
#df['region'] = df['abbrev'].map(region_map)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
fig=px.sunburst(df,
                path=['pickup_region','pickup_zone'],
                values='distance',
                color='pickup_region',
                color_continuous_scale='Reds'
                )
fig.show()
'''fig=px.sunburst(df,
                path=['region','abbrev'],
                values='speeding',
                title="Sunburst Chart of speeding accidents by Region and state",
                color='speeding',
                color_continuous_scale='Reds',
                template='plotly_dark')
fig.show()'''
# Out:
# 'fig=px.sunburst(df,\n                path=[\'region\',\'abbrev\'],\n                values=\'speeding\',\n                title="Sunburst Chart of speeding accidents by Region and state",\n                color=\'speeding\',\n                color_continuous_scale=\'Reds\',\n                template=\'plotly_dark\')\nfig.show()'

# %%
fig=px.scatter(df,x='pickup_zone',y='distance',color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
