# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#histogram of age
fig=sns.histplot(df,x="age",kde=True,color="blue",edgecolor="black")
fig.set_title("Age distribution of titanic passenger")
fig.set_xlabel("Age")
fig.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
#countplot:survival based on gender
fig=sns.countplot(df,x='survived',palette='RdBu',hue='sex')
fig.set_title("Survival Count of titanic Passengers")
fig.set_xlabel("survived")
fig.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
fig=sns.barplot(df,x='sex',y='fare',hue='class')
fig.set_title("Average Fare by Passenger Class and Gender")
fig.set_xlabel("sex")
fig.set_ylabel("Average Fare")
# Out:
# Text(0, 0.5, 'Average Fare')

# %%
fig=sns.countplot(df,x='class',palette='viridis')
fig.set_title("count of passengers by class")
fig.set_xlabel("passenger class")
fig.set_ylabel("count")
# Out:
# C:\Users\devbr\AppData\Local\Temp\ipykernel_24084\1248132163.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   fig=sns.countplot(df,x='class',palette='viridis')
# Text(0, 0.5, 'count')

# %%
sns.pairplot(df[['age','fare','survived','pclass']],hue='survived',palette='terrain')

# %% [markdown]
# # practise question

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(df,x="survived",y="age",hue="sex")

# %%
sns.catplot(df,x="survived",y="age",hue="sex",jitter=False)

# %%
sns.catplot(df,x="class",y="age",hue="sex",kind="swarm")
# Out:
# c:\Users\devbr\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\devbr\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\devbr\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\devbr\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(df,x="survived",y="age",hue="sex",native_scale=True)

# %%
sns.catplot(df,x="survived",y="age",hue="sex",order=['0'])

# %%
sns.catplot(df,x="survived",y="age",hue="sex",kind="box")

# %% [markdown]
# ## dodge topic is not clear

# %% [markdown]
# # by using sort values what happen

# %%
sns.catplot(df.sort_values("pclass"),x="survived",y="age",hue="sex")

# %%
sns.catplot(df,x="survived",y="age",hue="sex",kind="violin")

# %% [markdown]
# # what is use of bw_adjust

# %%
sns.catplot(df,x="survived",y="age",hue="sex",kind="violin",bw_adjust=.5,cut=0 )

# %%
sns.catplot(df,x="survived",y="age",hue="sex",kind="violin",split=True)

# %%
sns.catplot(df,x="survived",y="age",hue="sex",kind="violin",inner="stick")

# %% [markdown]
# # the swarm and violin plot are not overlapping

# %%
sns.catplot(df,x="survived",y="age",hue="sex",kind="violin",inner=None)
sns.swarmplot(df,x="survived",y="age",hue="sex")
# Out:
# c:\Users\devbr\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='survived', ylabel='age'>
# c:\Users\devbr\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
